# %%
import requests

BASE_URL = "http://127.0.0.1:8000"
APP_NAME = "travel_advisor_agent"
USER_ID = "u_123"
SESSOIN_ID = "cea1a81d-27c5-4970-a4c6-48927c698fd8"

# %%
# adk web 실행 시 session이 자동으로 생성되었었는데,
# 이를 API로 동일하게 구현하기 위해선 /apps/{app_name}/users/{user_id}/sessions 로 POST 요청
# -> session id 반환
response = requests.post(f"{BASE_URL}/apps/{APP_NAME}/users/{USER_ID}/sessions")
# {'id': '663fd92c-aced-4b8f-8cb7-32501ab0bf20', 'appName': 'travel_advisor_agent', 'userId': 'u_123', 'state': {}, 'events': [], 'lastUpdateTime': 1782737032.916954}
print(response.json())

# 다음으로는 run으로 agent 실행. (/run, /run_sse)
# 2가지 옵션이 있는데, 하나는 run이고 다른 하나는 run_sse임.
# 잠깐 SSE(server sent event)에 대해 설명하자면,
# HTTP는 상태가 없음. 무슨 말이냐면, 내가 서버에 요청을 보내면 연결이 되고 응답을 받은 뒤에 연결이 끊어지면 서버는 나를 까먹어버림.
# 그래서 쿠키나 토큰 같은게 필요함. 내가 서버에 요청을 보낼 때마다 서버가 준 쿠키를 같이 보냄으로서 서버는 내가 누군지 알게 됨.
# 근데 Server Sent Event는 서버가 실제로 연결 자체를 끊지 않고 나에게 이벤트를 보내줌.
# 이를 agent의 업데이트를 알려주는데에 사용함.
# Out:
# {'id': 'cea1a81d-27c5-4970-a4c6-48927c698fd8', 'appName': 'travel_advisor_agent', 'userId': 'u_123', 'state': {}, 'events': [], 'lastUpdateTime': 1782737661.916638}

# %%
# 여튼 run으로 agent 실행 시 appName, userId, sessionId 등 아래와 같은 값이 필요.
message = {
    "appName": APP_NAME,
    "userId": USER_ID,
    "sessionId": SESSOIN_ID,
    "newMessage": {
        "parts": [
            {"text": "I want to go to Tokyo"}
        ],
        "role": "user"
    }
}

response = requests.post(f"{BASE_URL}/run", json=message)

print(response.json())
# Out:
# [{'modelVersion': 'gpt-4o-2024-08-06', 'content': {'parts': [{'functionCall': {'id': 'call_ywevEnrbZZGREll92Af7Rjw6', 'args': {'location': 'Tokyo'}, 'name': 'get_weather'}}, {'functionCall': {'id': 'call_DADyDpO6lc9M4z8oCiFiItzu', 'args': {'location': 'Tokyo'}, 'name': 'get_local_attractions'}}], 'role': 'model'}, 'partial': False, 'finishReason': 'STOP', 'usageMetadata': {'cachedContentTokenCount': 0, 'candidatesTokenCount': 46, 'promptTokenCount': 408, 'totalTokenCount': 454}, 'invocationId': 'e-ae16a866-f295-4173-bb59-6dc9be186e4e', 'author': 'TravelAdvisorAgent', 'actions': {'stateDelta': {}, 'artifactDelta': {}, 'requestedAuthConfigs': {}, 'requestedToolConfirmations': {}}, 'nodeInfo': {'path': 'TravelAdvisorAgent@1'}, 'longRunningToolIds': [], 'id': '4e717bf7-c688-427f-948c-43c2c8ff4b9c', 'timestamp': 1782737675.861669}, {'content': {'parts': [{'functionResponse': {'id': 'call_ywevEnrbZZGREll92Af7Rjw6', 'name': 'get_weather', 'response': {'location': 'Tokyo', 'temperature': '22°C', 'condition': 'Partly cloudy', 'humidity': '65%', 'wind': '12 km/h', 'forecast': 'Mild weather with occasional clouds expected throughout the day'}}}, {'functionResponse': {'id': 'call_DADyDpO6lc9M4z8oCiFiItzu', 'name': 'get_local_attractions', 'response': {'location': 'Tokyo', 'category': 'all', 'attractions': [{'name': 'Tokyo Tower', 'type': 'landmark', 'rating': 4.5, 'description': 'Communications and observation tower'}, {'name': 'Senso-ji', 'type': 'temple', 'rating': 4.6, 'description': 'Ancient Buddhist temple'}, {'name': 'Shibuya Crossing', 'type': 'landmark', 'rating': 4.4, 'description': 'Busiest pedestrian crossing'}, {'name': 'Meiji Shrine', 'type': 'shrine', 'rating': 4.7, 'description': 'Shinto shrine dedicated to Emperor Meiji'}, {'name': 'Tokyo Skytree', 'type': 'tower', 'rating': 4.6, 'description': 'Broadcasting and observation tower'}], 'total_count': 5}}}], 'role': 'user'}, 'invocationId': 'e-ae16a866-f295-4173-bb59-6dc9be186e4e', 'author': 'TravelAdvisorAgent', 'actions': {'stateDelta': {}, 'artifactDelta': {}, 'requestedAuthConfigs': {}, 'requestedToolConfirmations': {}}, 'nodeInfo': {'path': 'TravelAdvisorAgent@1'}, 'id': 'd996821e-9c32-4a07-b148-4c663bd94f06', 'timestamp': 1782737682.214815}, {'modelVersion': 'gpt-4o-2024-08-06', 'content': {'parts': [{'text': "Visiting Tokyo sounds exciting! Here's some information to help you with your trip:\n\n### Current Weather:\n- **Temperature:** 22°C\n- **Condition:** Partly cloudy\n- **Humidity:** 65%\n- **Wind:** 12 km/h\n- **Forecast:** Mild weather with occasional clouds expected throughout the day.\n\n### Must-See Attractions:\n1. **Tokyo Tower**\n   - **Type:** Landmark\n   - **Rating:** 4.5\n   - **Description:** A communications and observation tower offering panoramic views of the city.\n\n2. **Senso-ji**\n   - **Type:** Temple\n   - **Rating:** 4.6\n   - **Description:** An ancient Buddhist temple known for its beautiful architecture and cultural significance.\n\n3. **Shibuya Crossing**\n   - **Type:** Landmark\n   - **Rating:** 4.4\n   - **Description:** Experience one of the busiest pedestrian crossings in the world, in the heart of Tokyo's bustling shopping district.\n\n4. **Meiji Shrine**\n   - **Type:** Shrine\n   - **Rating:** 4.7\n   - **Description:** A serene Shinto shrine dedicated to Emperor Meiji and Empress Shoken, set amidst a forested area.\n\n5. **Tokyo Skytree**\n   - **Type:** Tower\n   - **Rating:** 4.6\n   - **Description:** A broadcasting and observation tower, and the tallest structure in Japan, offering breathtaking views of the city.\n\n### Additional Tips:\n- Consider exploring local neighborhoods like Akihabara for electronic goods, Harajuku for fashion, and Asakusa for traditional shops and eateries.\n- Try authentic Japanese cuisine like sushi, ramen, and tempura.\n\nIf you have any more questions or need further assistance with your travel plans, feel free to ask!"}], 'role': 'model'}, 'partial': False, 'finishReason': 'STOP', 'usageMetadata ...

# %%
data = response.json()

for event in data:
    content = event.get("content")
    parts = content.get("parts")
    for part in parts:
        function_call = part.get("functionCall", None)
        if function_call:
            print(function_call.get("name"))
        text = part.get("text", None)
        if text:
            print(text)
        print("|||||" * 60)
    print("=" * 60)
# Out:
# get_weather
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# get_local_attractions
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ============================================================
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ============================================================
# Visiting Tokyo sounds exciting! Here's some information to help you with your trip:
#
# ### Current Weather:
# - **Temperature:** 22°C
# - **Condition:** Partly cloudy
# - **Humidity:** 65%
# - **Wind:** 12 km/h
# - **Forecast:** Mild weather with occasional clouds expected throughout the day.
#
# ### Must-See Attractions:
# 1. **Tokyo Tower**
#    - **Type:** Landmark
#    - **Rating:** 4.5
#    - **Description:** A communications and observation tower offering panoramic views of the city.
#
# 2. **Senso-ji**
#    - **Type:** Temple
#    - **Rating:** 4.6
#    - **Description:** An ancient Buddhist temple known for its beautiful architecture and cultural significance.
#
# 3. **Shibuya Crossing**
#    - **Type:** Landmark
#    - **Rating:** 4.4
#    - **Description:** Experience one of the busiest pedestrian crossings in the world, in the heart of Tokyo's bustling shopping district.
#
# 4. **Meiji Shrine**
#    - **Type:** Shrine
#    - **Rating:** 4.7
#    - **Description:** A serene Shinto shrine dedicated to Emperor Meiji and Empress Shoken, set amidst a forested area.
#
# 5. **Tokyo Skytree**
#    - **Type:** Tower
#    - **Rating:** 4.6
#    - **Description:** A broadcasting and observation tower, and the tallest structure in Japan, offering breathtaking views of the city.
#
# ### Additional Tips:
# - Consider exploring local neighborhoods like Akihabara for electronic goods, Harajuku for fashion, and Asakusa for traditional shops and eateries.
# - Try authentic Japanese cuisine like sushi, ramen, and tempura.
#
# If you have any more questions or need further assistance with your travel plans, feel free to ask!
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ============================================================
