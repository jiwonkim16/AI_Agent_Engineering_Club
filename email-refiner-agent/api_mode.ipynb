# %%
import requests
import sseclient
import json

BASE_URL = "http://127.0.0.1:8000"
APP_NAME = "travel_advisor_agent"
USER_ID = "u_123"
SESSOIN_ID = "25745dc0-e59d-487e-a53c-ba39814870bb"

# %%
# adk web 실행 시 session이 자동으로 생성되었었는데,
# 이를 API로 동일하게 구현하기 위해선 /apps/{app_name}/users/{user_id}/sessions 로 POST 요청
# -> session id 반환
response = requests.post(f"{BASE_URL}/apps/{APP_NAME}/users/{USER_ID}/sessions")
# {'id': '663fd92c-aced-4b8f-8cb7-32501ab0bf20', 'appName': 'travel_advisor_agent', 'userId': 'u_123', 'state': {}, 'events': [], 'lastUpdateTime': 1782737032.916954}
print(response.json())

# 다음으로는 run으로 agent 실행. (/run, /run_sse)
# 2가지 옵션이 있는데, 하나는 run이고 다른 하나는 run_sse임.
# 잠깐 SSE(server sent event)에 대해 설명하자면,
# HTTP는 상태가 없음. 무슨 말이냐면, 내가 서버에 요청을 보내면 연결이 되고 응답을 받은 뒤에 연결이 끊어지면 서버는 나를 까먹어버림.
# 그래서 쿠키나 토큰 같은게 필요함. 내가 서버에 요청을 보낼 때마다 서버가 준 쿠키를 같이 보냄으로서 서버는 내가 누군지 알게 됨.
# 근데 Server Sent Event는 서버가 실제로 연결 자체를 끊지 않고 나에게 이벤트를 보내줌.
# 이를 agent의 업데이트를 알려주는데에 사용함.
# Out:
# {'id': '25745dc0-e59d-487e-a53c-ba39814870bb', 'appName': 'travel_advisor_agent', 'userId': 'u_123', 'state': {}, 'events': [], 'lastUpdateTime': 1782819012.020471}

# %%
# 여튼 run으로 agent 실행 시 appName, userId, sessionId 등 아래와 같은 값이 필요.
message = {
    "appName": APP_NAME,
    "userId": USER_ID,
    "sessionId": SESSOIN_ID,
    "newMessage": {
        "parts": [
            {"text": "I want to go to Tokyo"}
        ],
        "role": "user"
    },
    "streaming": True
}

response = requests.post(f"{BASE_URL}/run_sse", json=message, stream=True)

client = sseclient.SSEClient(response)

for event in client.events():
    data = json.loads(event.data)
    content = data.get("content")
    parts = content.get("parts")
    for part in parts:
        function_call = part.get("functionCall", None)
        if function_call:
            print(function_call.get("name"))
        text = part.get("text", None)
        if text:
            print(text)
        print("|||||" * 60)
    print("=" * 60)
# Out:
# Tokyo is a vibrant city with a mix of traditional culture and ultramodern living. To help you plan your trip, I'll provide some information on the current weather, popular attractions, and currency exchange rates.
#
# Let me gather this information for you.
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# get_weather
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# get_local_attractions
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# get_exchange_rate
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ============================================================
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ============================================================
# Here's some useful information to plan your trip to Tokyo:
#
# ### Weather
# - **Current Temperature**: 22°C
# - **Condition**: Partly cloudy
# - **Humidity**: 65%
# - **Wind**: 12 km/h
# - **Forecast**: Mild weather with occasional clouds expected throughout the day
#
# ### Popular Attractions in Tokyo
# 1. **Tokyo Tower**: A communications and observation tower, rated 4.5/5.
# 2. **Senso-ji**: An ancient Buddhist temple, rated 4.6/5.
# 3. **Shibuya Crossing**: The busiest pedestrian crossing in the world, rated 4.4/5.
# 4. **Meiji Shrine**: A Shinto shrine dedicated to Emperor Meiji, rated 4.7/5.
# 5. **Tokyo Skytree**: A broadcasting and observation tower, rated 4.6/5.
#
# ### Currency Exchange
# - **Exchange Rate**: 1 USD = 149.5 JPY
#
# If you have any more questions or need further assistance, feel free to ask! Enjoy your trip to Tokyo!
# ||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||
# ============================================================
